# %% [markdown]
# The goal is to train a parametric circuit to fit the **Up-Quark's Parton Distribution Fucntion**.
#
# What is Parton Distribution Function (PDF) ?
#
# PDFs are probability distribution functions that describe the probability of finding a parton (quark, antiquark, or gluon) carrying a fraction x of the proton's momentum at a given energy scale Q^2.
# - PDFs provide insights into the internal structure of protons, revealing how quarks and gluons are distributed within.
# - PDFs are essential for predicting the outcomes of high energy particle collisions as those in LHC.
#
# Energy Scale (Q^2) determines the resolution at which the proton's structure is probed.

# %%
pip install qibo
# Out:
# Requirement already satisfied: qibo in /usr/local/lib/python3.10/dist-packages (0.2.13)
# Requirement already satisfied: cma<4.0.0,>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from qibo) (3.4.0)
# Requirement already satisfied: joblib<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from qibo) (1.4.2)
# Requirement already satisfied: networkx<4.0.0,>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from qibo) (3.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26.4 in /usr/local/lib/python3.10/dist-packages (from qibo) (1.26.4)
# Requirement already satisfied: openqasm3>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from openqasm3[parser]>=0.5.0->qibo) (1.0.0)
# Requirement already satisfied: optuna<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from qibo) (4.0.0)
# Requirement already satisfied: scipy<2.0.0,>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from qibo) (1.13.1)
# Requirement already satisfied: sympy<2.0.0,>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from qibo) (1.13.1)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from qibo) (0.9.0)
# Requirement already satisfied: antlr4-python3-runtime<4.14,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openqasm3[parser]>=0.5.0->qibo) (4.13.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo) (6.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy<2.0.0,>=1.11.1->qibo) (1.3.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna<5.0.0,>=4.0.0->qibo) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna<5.0.0,>=4.0.0->qibo) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna<5.0.0,>=4.0.0->qibo) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna<5.0.0,>=4.0.0->qibo) (3.0.2)

# %%
pip install qibojit
# Out:
# Collecting qibojit
#   Downloading qibojit-0.1.7-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: numba>=0.59.0 in /usr/local/lib/python3.10/dist-packages (from qibojit) (0.60.0)
# Requirement already satisfied: psutil<6.0.0,>=5.9.5 in /usr/local/lib/python3.10/dist-packages (from qibojit) (5.9.5)
# Requirement already satisfied: qibo<0.3.0,>=0.2.13 in /usr/local/lib/python3.10/dist-packages (from qibojit) (0.2.13)
# Requirement already satisfied: scipy<2.0.0,>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from qibojit) (1.13.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.59.0->qibojit) (0.43.0)
# Requirement already satisfied: numpy<2.1,>=1.22 in /usr/local/lib/python3.10/dist-packages (from numba>=0.59.0->qibojit) (1.26.4)
# Requirement already satisfied: cma<4.0.0,>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.13->qibojit) (3.4.0)
# Requirement already satisfied: joblib<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.13->qibojit) (1.4.2)
# Requirement already satisfied: networkx<4.0.0,>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.13->qibojit) (3.4.2)
# Requirement already satisfied: openqasm3>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from openqasm3[parser]>=0.5.0->qibo<0.3.0,>=0.2.13->qibojit) (1.0.0)
# Requirement already satisfied: optuna<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.13->qibojit) (4.0.0)
# Requirement already satisfied: sympy<2.0.0,>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.13->qibojit) (1.13.1)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.13->qibojit) (0.9.0)
# Requirement already satisfied: antlr4-python3-runtime<4.14,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openqasm3[parser]>=0.5.0->qibo<0.3.0,>=0.2.13->qibojit) (4.13.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.13->qibojit) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.13->qibojit) (6.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.13->qibojit) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.13->qibojit) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.13->qibojit) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.13->qibojit) (6.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy<2.0.0,>=1.11.1->qibo<0.3.0,>=0.2.13->qibojit) (1.3.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.13->qibojit) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.13->qibojit) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.13->qibojit) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.13->qibojit) (3.0.2)
# Downloading qibojit-0.1.7-py3-none-any.whl (36 kB)
# Installing collected packages: qibojit
# Successfully installed qibojit-0.1.7

# %%
pip install git+https://github.com/qiboteam/qiboedu
# Out:
# Collecting git+https://github.com/qiboteam/qiboedu
#   Cloning https://github.com/qiboteam/qiboedu to /tmp/pip-req-build-owzb0eni
#   Running command git clone --filter=blob:none --quiet https://github.com/qiboteam/qiboedu /tmp/pip-req-build-owzb0eni
#   Resolved https://github.com/qiboteam/qiboedu to commit c05f53215f1e0efff377a0310748b8dc3753dac7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib<4.0.0,>=3.8.0 in /usr/local/lib/python3.10/dist-packages (from qiboedu==0.1.0) (3.8.0)
# Requirement already satisfied: qibo<0.3.0,>=0.2.4 in /usr/local/lib/python3.10/dist-packages (from qiboedu==0.1.0) (0.2.13)
# Requirement already satisfied: qibojit<0.2.0,>=0.1.2 in /usr/local/lib/python3.10/dist-packages (from qiboedu==0.1.0) (0.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.8.0->qiboedu==0.1.0) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.8.0->qiboedu==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.8.0->qiboedu==0.1.0) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.8.0->qiboedu==0.1.0) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.8.0->qiboedu==0.1.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.8.0->qiboedu==0.1.0) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.8.0->qiboedu==0.1.0) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.8.0->qiboedu==0.1.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.8.0->qiboedu==0.1.0) (2.8.2)
# Requirement already satisfied: cma<4.0.0,>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (3.4.0)
# Requirement already satisfied: joblib<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (1.4.2)
# Requirement already satisfied: networkx<4.0.0,>=3.2.1 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (3.4.2)
# Requirement already satisfied: openqasm3>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from openqasm3[parser]>=0.5.0->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (1.0.0)
# Requirement already satisfied: optuna<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (4.0.0)
# Requirement already satisfied: scipy<2.0.0,>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (1.13.1)
# Requirement already satisfied: sympy<2.0.0,>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (1.13.1)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (0.9.0)
# Requirement already satisfied: numba>=0.59.0 in /usr/local/lib/python3.10/dist-packages (from qibojit<0.2.0,>=0.1.2->qiboedu==0.1.0) (0.60.0)
# Requirement already satisfied: psutil<6.0.0,>=5.9.5 in /usr/local/lib/python3.10/dist-packages (from qibojit<0.2.0,>=0.1.2->qiboedu==0.1.0) (5.9.5)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.59.0->qibojit<0.2.0,>=0.1.2->qiboedu==0.1.0) (0.43.0)
# Requirement already satisfied: antlr4-python3-runtime<4.14,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openqasm3[parser]>=0.5.0->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (4.13.2)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (6.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.8.0->qiboedu==0.1.0) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy<2.0.0,>=1.11.1->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (1.3.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna<5.0.0,>=4.0.0->qibo<0.3.0,>=0.2.4->qiboedu==0.1.0) (3.0.2)
# Building wheels for collected packages: qiboedu
#   Building wheel for qiboedu (pyproject.toml) ... done
#   Created wheel for qiboedu: filename=qiboedu-0.1.0-py3-none-any.whl size=17156 sha256=56c137a9dd27f211d0a91abcecfba4ce11b706575eda0660b3324fdf093cf208
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l6fedrhl/wheels/88/3e/b3/56312e57970f2fabccd0b51c358665866db085f22720ced56a
# Successfully built qiboedu
# Installing collected packages: qiboedu
# Successfully installed qiboedu-0.1.0

# %%
import matplotlib.pyplot as plt
import numpy as np
import qibo
from qibo import Circuit, gates, hamiltonians

# %%
from qibo.optimizers import optimize

# %%
qibo.list_available_backends()
# Out:
# {'numpy': True, 'pytorch': True, 'qulacs': False}

# %%
from sys import platform
qibo.set_backend('qibojit')
# Out:
# [Qibo 0.2.13|INFO|2024-11-10 06:08:57]: Using qibojit (numba) backend on /CPU:0
# INFO:qibo.config:Using qibojit (numba) backend on /CPU:0

# %%
dt = np.loadtxt("/content/datau.dat")
x_lables = dt[:, 0]
y_lables = dt[:, 1]
indices = np.arange(0, len(y_lables), 4)
selected_features = x_lables[indices]
selected_labels = y_lables[indices]

# %%
def plot_uquark(x, y,predictions=None):
    plt.plot(x_lables, y_lables, label="Target",marker='o', linestyle='-',color='pink')
    plt.xlabel("Momentum Fraction x ")
    plt.ylabel("Parton Distribution Function")
    plt.title("Up-quark PDF")
    plt.legend()
    plt.grid(True)
    plt.show()
    if predictions is not None:
        plt.plot(x, predictions, color="purple", ls="-", lw=1.5, label="Predictions", marker=".", markersize=10, alpha=0.7)
    plt.grid(True)
    plt.xlabel("Momentum Fraction x ")
    plt.ylabel("Parton Distribution Function")
    plt.legend()
    plt.show()

plot_uquark(x_lables, y_lables)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def set_parameters(circuit, nlayers, parameters, x):
    """
    Upload data and trainable parameters into a circuit.
    We want to combine data and params so that angle = p1 * x + p2
    """
    params = []
    index = 0
    for _ in range(nlayers):
        params.append(parameters[index] * x + parameters[index + 1])
        params.append(parameters[index + 2] * np.log(x) + parameters[index + 3])
        index += 4
    circuit.set_parameters(params)
    return circuit

# %%
def predict(parameters, dt, nlayers, circuit, hamiltonian):
    """Compute predictions given dataset and parameters."""
    predictions = []
    for x in dt:
        circuit = set_parameters(circuit, nlayers, parameters, x)
        predictions.append(hamiltonian.expectation(circuit().state()))
    return predictions

# %%
def loss_function(parameters, dt, labels, circuit, nlayers, hamiltonian):
    """Compute loss function considering all data and a given set of parameters."""
    loss = 0
    predictions = predict(parameters, dt, nlayers, circuit, hamiltonian)
    for i, pred in enumerate(predictions):
        loss += (pred - labels[i])**2
    return loss / len(labels)

# %%
def build_parametric_circuit(nlayers):
    c = Circuit(1)
    for _ in range(nlayers):
        c.add(gates.RY(q=0, theta=0.))
        c.add(gates.RZ(q=0, theta=0.))

    c.add(gates.M(0))
    return c

# %%
# defining the parametric quantum circuit
nlayers = 2
pqc = build_parametric_circuit(nlayers)

np.random.seed(42)
initial_parameters = np.random.randn(nlayers * 4)
pqc = set_parameters(pqc, nlayers, initial_parameters, 0.3)

# defining the observable
h = hamiltonians.Z(1)

# %%
predictions = predict(initial_parameters, x_lables, nlayers, pqc, h)
plot_uquark(x_lables, y_lables, predictions)

# %%
optimization_result = optimize(loss_function, initial_parameters=initial_parameters, method="cma", args=(x_lables, y_lables, pqc, nlayers, h), options={"maxiter": 500})
# Out:
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 8 (seed=340011, Sun Nov 10 07:03:23 2024)
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 8.722168633529313e-02 1.0e+00 1.68e+00  2e+00  2e+00 0:00.9
#     2     20 3.589137925487699e-02 1.2e+00 1.70e+00  2e+00  2e+00 0:01.9
#     3     30 1.390936328458378e-01 1.3e+00 1.58e+00  1e+00  2e+00 0:02.9
#    10    100 1.781251774140760e-01 1.7e+00 1.41e+00  1e+00  2e+00 0:06.2
#    22    220 6.991433583102889e-02 2.5e+00 9.57e-01  7e-01  1e+00 0:10.4
#    36    360 6.798672374588489e-02 2.5e+00 9.17e-01  6e-01  9e-01 0:15.4
#    52    520 1.653823694752288e-02 2.9e+00 4.25e-01  2e-01  4e-01 0:21.7
#    72    720 1.496268925505640e-02 4.8e+00 2.97e-01  1e-01  4e-01 0:28.8
#    93    930 5.066910210056980e-03 8.0e+00 1.66e-01  5e-02  2e-01 0:37.1
#   100   1000 4.611259876697342e-03 1.1e+01 2.18e-01  6e-02  3e-01 0:39.5
#   126   1260 3.494672348524471e-03 2.3e+01 6.53e-02  8e-03  1e-01 0:49.8
#   155   1550 3.073006670512616e-03 4.7e+01 1.25e-01  1e-02  2e-01 1:01.0
#   187   1870 1.347531420476162e-03 6.5e+01 1.39e-01  8e-03  2e-01 1:13.2
#   200   2000 1.142027629675887e-03 9.1e+01 1.23e-01  6e-03  2e-01 1:17.7
#   237   2370 2.026663148946528e-04 1.2e+02 1.73e-01  8e-03  3e-01 1:31.7
#   277   2770 1.116954555551951e-04 1.8e+02 1.13e-01  3e-03  2e-01 1:46.8
#   300   3000 1.096493416854159e-04 2.7e+02 2.21e-02  3e-04  4e-02 1:55.5
#   346   3460 1.096023320967662e-04 8.4e+02 7.04e-04  5e-06  1e-03 2:12.8
#   374   3740 1.096023298559098e-04 1.1e+03 6.18e-05  2e-07  9e-05 2:23.5

# %%
params = optimization_result[1]
predictions = predict(params, x_lables, nlayers, pqc, h)
plot_uquark(x_lables,y_lables, predictions)

# %% [markdown]
# Once the circuit has been trained successfully, this model can be used for a number of applictaions in HEP:
#
# - Used in Monto Carlo Simulations to generate more accurate predictions for particle collisions at High Energy Physics experiements.
# - Up-Quark PDF helps us get an understanding of proton's internal structure.
#
# The fitted PDF can be used to test the predictions of the standard model with higher precision.
